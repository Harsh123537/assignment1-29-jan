# %% [markdown]
# ![image.png](attachment:4f728a19-ff42-4c2b-b063-3b40bf95d804.png)

# %% [markdown]
# Python Programming language was developed by a guido van rossum.

# %% [markdown]
# ![image.png](attachment:c10f0a62-205b-4f72-beb0-d8cbb11bf93f.png)

# %% [markdown]
# Python is an interpreted programming language, supporting object-oriented, structured
# and functional programming.

# %% [markdown]
# ![image.png](attachment:b07f8d50-b461-4a41-9620-85b0670a17b3.png)

# %% [markdown]
# Yes, Python is case sensitive when dealing with identifiers.

# %% [markdown]
# ![image.png](attachment:0ad83cc2-4b73-452d-8912-a4e71a0aa2de.png)

# %% [markdown]
# The correct extension of the python file is .py

# %% [markdown]
# ![image.png](attachment:3a444911-990e-4634-b11e-c4e28f84a3ca.png)

# %% [markdown]
# Python code is interpreted.

# %% [markdown]
# ![image.png](attachment:68b2eebf-4f8b-4dc9-98d0-3e0055cf3d17.png)

# %% [markdown]
# Name of few blocks of code are if,else,def,for,while,etc.

# %% [markdown]
# ![image.png](attachment:03087776-edcc-4de1-93e0-24cd0eb17dac.png)

# %% [markdown]
# '#' is used to used to give single line comments.

# %% [markdown]
# ![image.png](attachment:3322cb68-c2c2-414c-b80d-2438dfbc4938.png)

# %% [markdown]
# Using sys.version method
# Using python_version() function
# Using Python -V command

# %% [markdown]
# ![image.png](attachment:e043b871-b302-4d8c-9168-a260bb8eebb0.png)

# %% [markdown]
# Lamda function

# %% [markdown]
# ![image.png](attachment:ae6a6ec2-5b2e-48c8-8d01-9e0756917929.png)

# %% [markdown]
# pip stands for "preferred installer program".

# %% [markdown]
# ![image.png](attachment:9e977a65-b2dc-4a7a-9520-432909c88890.png)

# %% [markdown]
# print(),type(),python_version(),upper(),len(),max(),min().

# %% [markdown]
# ![image.png](attachment:915f8d01-5090-479a-bf2f-da5eab8404ec.png)

# %% [markdown]
# Maximum possible length of an identifier in python of 79 character.

# %% [markdown]
# ![image.png](attachment:3c47ed8f-ceb3-4069-a0e9-181410ef1ebb.png)

# %% [markdown]
# Benefits of using python are:
# easy to learn.
# have many built in libraries.
# used in data science
# used in web development

# %% [markdown]
# ![image.png](attachment:d541d859-332f-47d0-b163-da9249b82bf6.png)

# %% [markdown]
# Memory managed in python through private heap.

# %% [markdown]
# ![image.png](attachment:2bdaf81b-4bf5-48d7-859a-58b755732d6b.png)

# %% [markdown]
# Python can be downloaded through python.org officialy website and for adding path following is the way:
# Right-clicking This PC and going to Properties.
#
# Clicking on the Advanced system settings in the menu on the left.
#
# Clicking on the Environment Variables button on the bottom right.
#
# In the System variables section, selecting the Path variable and clicking on Edit. The next screen will show all the directories that are currently a part of the PATH variable.
#
# Clicking on New and entering Python’s install directory.

# %% [markdown]
# ![image.png](attachment:a59d3a58-ace5-4a3b-8060-ca76ba459b7c.png)

# %% [markdown]
# yes identation is required in python.
